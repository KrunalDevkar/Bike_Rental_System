# %%
class bikeShop:
    
    def __init__(self,stock):
        self.stock=stock
    def displayBike(self):
        print("Total Bikes Available",self.stock)
    def rentForBike(self,q):
        
        if q<=0:
            print("Enter the positive value or greater than zero")
        elif q>self.stock:
            print("Enter the Value (less than stock)")
        else:
            self.stock=self.stock-q
            print("Total Prices",q*100)
            print("Total Bikes",self.stock)
            
while True:
    obj=bikeShop(100)
    uc=int(input('''
    1. Display Stocks
    2. Rent a Bike
    3. Exit
    '''
    ))
    
    if uc==1:
        obj.displayBike()
    elif uc==2:
        n=int(input("Enter the Qty:---"))
        obj.rentForBike(n)
    else:
        break
# Out:
#     1. Display Stocks
#     2. Rent a Bike
#     3. Exit
#     1
# Total Bikes Available 100
#
#     1. Display Stocks
#     2. Rent a Bike
#     3. Exit
#     2
# Enter the Qty:---20
# Total Prices 2000
# Total Bikes 80
#
#     1. Display Stocks
#     2. Rent a Bike
#     3. Exit
#     3

# %%
class bikeShop:
    
    def __init__(self,stock):
        self.stock=stock
    def displayBike(self):
        print("Total Bikes Available",self.stock)
    def rentForBike(self,q):
        
        if q<0:
            print("Enter the Positive value or greater value")
        elif q>self.stock:
            print("Enter the value (less than Stock)")
        else:
            self.stock=self.stock-q
            print("Total Price",q*100)
            print("Total Stock left",self.stock)
            
while True:
    obj=bikeShop(100)
    uc=int(input('''
    1. Display Stock
    2. Rent a Bike
    3. Exit
    '''
    ))
    
    if uc==1:
        obj.displayBike()
    elif uc==2:
        n=int(input("Enter the Qty:---"))
        obj.rentForBike(n)
    else:
        break
# Out:
#     1. Display Stock
#     2. Rent a Bike
#     3. Exit
#     2
# Enter the Qty:---10
# Total Price 1000
# Total Stock left 90
#
#     1. Display Stock
#     2. Rent a Bike
#     3. Exit
#     3

# %%
class bikeShop:
    
    def __init__(self,stock):
        self.stock=stock
    def displayBike(self):
        print("Total Bikes Available",self.stock)
    def rentForBike(self,q):
        
        if q<0:
            print("Enter the Positive value or greater value")
        elif q>self.stock:
            print("Enter the value (less than Stock)")
        else:
            self.stock=self.stock-q
            print("Total Price",q*100)
            print("Total Stock left",self.stock)
            
while True:
    obj=bikeShop(100)
    uc=int(input('''
    1. Display Stock
    2. Rent a Bike
    3. Exit
    '''))
    
    if uc==1:
        obj.displayBike()
    elif uc==2:
        n=int(input("Enter the Qty:---"))
        obj.rentForBike(n)
    else:
        break
# Out:
#     1. Display Stock
#     2. Rent a Bike
#     3. Exit
#     2
# Enter the Qty:---1000
# Enter the value (less than Stock)
#
#     1. Display Stock
#     2. Rent a Bike
#     3. Exit
#     2
# Enter the Qty:---100
# Total Price 10000
# Total Stock left 0
#
#     1. Display Stock
#     2. Rent a Bike
#     3. Exit
#     3
